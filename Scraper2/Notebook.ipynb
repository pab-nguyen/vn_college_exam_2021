# %%
import pandas as pd

# %%
df = pd.read_csv('score2021.csv')

# %%
df.head()
# Out:
#    STT  Cụm Thi  Họ Tên      SBD  Ngày sinh  Giới tính  Toán (D1)  \
# 0  1.0      NaN     NaN  1000001        NaN        NaN        2.2
# 1  1.0      NaN     NaN  1000002        NaN        NaN        9.2
# 2  1.0      NaN     NaN  1000003        NaN        NaN        4.4
# 3  1.0      NaN     NaN  1000004        NaN        NaN        8.4
# 4  1.0      NaN     NaN  1000005        NaN        NaN        8.8
#
#    Ngữ văn (D2)  Vật lí (D3)  Hóa học (D4)  Sinh học (D5)  KHTN (D6)  \
# 0          3.50          NaN           NaN            NaN        NaN
# 1          8.25          NaN           NaN            NaN        NaN
# 2          6.25          NaN           NaN            NaN        NaN
# 3          6.75         4.00          3.00           3.50        NaN
# 4          8.25         8.25          5.75           5.25        NaN
#
#    Lịch sử (D7)  Địa lí (D8)  GDCD (D9)  KHXH (D10)  Ngoại ngữ (D11)  D12
# 0          2.50         5.50        NaN         NaN              NaN  NaN
# ...

# %%
df.dim()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e6175b366d57> in <module>
# ----> 1 df.dim()
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dim'
